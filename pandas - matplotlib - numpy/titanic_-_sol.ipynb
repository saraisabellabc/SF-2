# %% [markdown]
# import all necessary libraries (i.e. pandas and matplotlib)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read the provided file `titanic.csv` into a DataFrame

# %%
# your code here
titanic_df = pd.read_csv('titanic.csv')

# %% [markdown]
# print the following
# - entries from the data frame
# - descriptive statistics, what is the average age, the maximum number of siblings and children?
# - general information
# - first 5 entries
# - first 15 entries
# - last 5 entries
# - last 15 entries
# - sample of random 10 entries

# %%
# titanic_df
# titanic_df.describe()
# titanic_df.info()
# titanic_df.head()
# titanic_df.head(15)
# titanic_df.tail()
# titanic_df.tail(15)
titanic_df.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp      fare   class    who  \
# 756         0       3    male  28.0      0    7.7958   Third    man
# 716         1       1  female  38.0      0  227.5250   First  woman
# 734         0       2    male  23.0      0   13.0000  Second    man
# 494         0       3    male  21.0      0    8.0500   Third    man
# 428         0       3    male   NaN      0    7.7500   Third    man
# 692         1       3    male   NaN      0   56.4958   Third    man
# 786         1       3  female  18.0      0    7.4958   Third  woman
# 57          0       3    male  28.5      0    7.2292   Third    man
# 320         0       3    male  22.0      0    7.2500   Third    man
# 606         0       3    male  30.0      0    7.8958   Third    man
#
#      adult_male deck  embark_town alive  alone
# 756        True  NaN  Southampton    no   True
# 716       False    C    Cherbourg   yes   True
# 734        True  NaN  Southampton    no   True
# 494        True  NaN  Southampton    no   True
# 428        True  NaN   Queenstown    no   True
# 692        True  NaN  Southampton   yes   True
# 786       False  NaN  Southampton   yes   True
# 57         True  NaN    Cherbourg    no   True
# 320        True  NaN  Southampton    no   True
# 606        True  NaN  Southampton    no   True

# %% [markdown]
# draw a histogram for age distribution using `matplotlib`

# %%
ages = titanic_df['age']
ages.hist()
plt.show()

# %% [markdown]
# - Create a new DataFrame with only entries where age > 30.
# - Give number of such entires
# - show only the women entries, how many  are there over the age of 30
# - the men entries, how many men are there over the age of 30
# - plot the new histogram for all ages >30, how does this histogram differ from the one you plotted above?

# %%
age_filter = titanic_df['age'] > 30
age_over_30_df = titanic_df[age_filter]
# age_over_30_df.value_counts()

# # women entries
# # women_filter = age_over_30_df['who']=='woman'
# # age_over_30_df[women_filter]

# # men entries
# men_filter = age_over_30_df['who'] == 'man'
# age_over_30_df[men_filter]

# plot histogram
ages = age_over_30_df['age']
ages.hist()
plt.show()

# %% [markdown]
# Use `pandas` to plot the pie chart of all classes on board the titanic.

# %%
titanic_df['class'].value_counts().plot(kind='pie', title='class on the titanic') #, figsize=(10, 10)
# Out:
# <Axes: title={'center': 'class on the titanic'}, ylabel='count'>

# %% [markdown]
# use `pandas` to plot the bar chart of all towns that people embarked from.

# %%
titanic_df['embark_town'].value_counts().plot(kind='bar', title='Titanic: embarked towns')
# Out:
# <Axes: title={'center': 'Titanic: embarked towns'}, xlabel='embark_town'>

# %% [markdown]
# # part 2

# %% [markdown]
# - Create a new DataFrame with 3 columns: fare, class, embark_town.
# - Clean your data from all `NaN` values.
# - Sort your DataFrame by fare in decreasing order.
# - Sort the same data frame in alphabetical order of the embarked_town.

# %%
fare_class_town_df = titanic_df[['fare', 'class', 'embark_town']]
fare_class_town_df = fare_class_town_df.dropna()
# fare_class_town_df.sort_values(by=['fare'], ascending = False)
fare_class_town_df.sort_values(by=['embark_town'])
# Out:
#          fare   class  embark_town
# 258  512.3292   First    Cherbourg
# 125   11.2417   Third    Cherbourg
# 354    7.2250   Third    Cherbourg
# 352    7.2292   Third    Cherbourg
# 128   22.3583   Third    Cherbourg
# ..        ...     ...          ...
# 351   35.0000   First  Southampton
# 353   17.8000   Third  Southampton
# 355    9.5000   Third  Southampton
# 344   13.0000  Second  Southampton
# 445   81.8583   First  Southampton
#
# [889 rows x 3 columns]

# %% [markdown]
# Create a new DataFrame that holds all entries with classes 2 or 3.  Plot the histogram of the classes 2 and 3.
# In pandas `&` corresponds to logical `and`, and `|` corresponds to logical `or`

# %%
class_23_filter = (titanic_df['pclass'] == 2) | (titanic_df['pclass'] == 3)
class_23_df = titanic_df[class_23_filter]
class_23_df

plt.hist(class_23_df['pclass'])


# or can also do it this way:
# class_23_df_v2 = titanic_df[titanic_df['pclass'].isin([2,3])]
# class_23_df_v2
# Out:
# (array([184.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 491.]),
#  array([2. , 2.1, 2.2, 2.3, 2.4, 2.5, 2.6, 2.7, 2.8, 2.9, 3. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Customize row indices such that indices are according to embarked town, drop all `NaN` values, and sort in alphabetical order of embarked town.

# %%
titanic_by_town_df = titanic_df.set_index('embark_town')
titanic_by_town_df.dropna().sort_values(by='embark_town')
# Out:
#              survived  pclass     sex   age  sibsp      fare  class    who  \
# embark_town
# Cherbourg           1       1  female  38.0      1   71.2833  First  woman
# Cherbourg           0       1    male  18.0      1  108.9000  First    man
# Cherbourg           1       1  female  54.0      1   78.2667  First  woman
# Cherbourg           0       1    male  58.0      0   29.7000  First    man
# Cherbourg           1       1    male  25.0      1   91.0792  First    man
# ...               ...     ...     ...   ...    ...       ...    ...    ...
# Southampton         1       1    male  52.0      0   30.5000  First    man
# Southampton         0       1    male  47.0      0   52.0000  First    man
# Southampton         0       1    male  65.0      0   26.5500  First    man
# NaN                 1       1  female  38.0      0   80.0000  First  woman
# NaN                 1       1  female  62.0      0   80.0000  First  woman
#
#              adult_male deck alive  alone
# embark_town
# Cherbourg         False    C   yes  False
# Cherbourg          True    C    no  False
# Cherbourg         False    D   yes  False
# Cherbourg          True    B    no   True
# Cherbourg          True    B   yes  False
# ...                 ...  ...   ...    ...
# Southampton        True    C   yes   True
# Southampton        True    C    no   True
# Southampton        True    E    no   True
# NaN               False    B   yes   True
# NaN               False    B   yes   True
#
# [184 rows x 12 columns]

# %% [markdown]
# Let's aggregate data into groups
# - get the number of entries from each class (i.e. pclass column in csv file). How many people are in first class, how many in second class and how many in third?
# - get number of entries from each town.  There are a total of how many towns that people embarked from?
# - get general summary of each class, round the date to 2 decimal places and display your data such that the three classes are shown as columns
# - get the number of suvivors and non-survivors in each class.
# - show full DataFrame of how many children, women and men are in each of the three classes.
# - plot women, men, children according to class

# %%
titanic_df.groupby('pclass').size()
titanic_df.groupby('embark_town').size()
titanic_df.groupby('pclass').describe().round(2).T
titanic_df.groupby(['pclass', 'survived']).size()
titanic_df.groupby(['pclass', 'who']).count()
# Out:
#               survived  sex  age  sibsp  fare  class  adult_male  deck  \
# pclass who
# 1      child         6    6    6      6     6      6           6     6
#        man         119  119   98    119   119    119         119    91
#        woman        91   91   82     91    91     91          91    78
# 2      child        19   19   19     19    19     19          19     4
#        man          99   99   90     99    99     99          99     3
#        woman        66   66   64     66    66     66          66     9
# 3      child        58   58   58     58    58     58          58     3
#        man         319  319  225    319   319    319         319     5
#        woman       114  114   72    114   114    114         114     4
#
#               embark_town  alive  alone
# pclass who
# 1      child            6      6      6
#        man            119    119    119
#        woman           89     91     91
# 2      child           19     19     19
#        man             99     99     99
#        woman           66     66     66
# 3      child           58     58     58
#        man            319    319    319
#        woman          114    114    114

# %% [markdown]
# plot a bar graph with the number of children, women and men for each class of ticket

# %%
# fig, ax = plt.subplots(figsize=(7, 7))
# titanic_df.groupby(['pclass', 'who']).count()['class'].unstack().plot.bar(ax = ax, title = 'TITLE',
#     ylabel = 'number of people', xlabel = 'class')


titanic_df.groupby(['pclass', 'who']).size().plot.bar(title='Class distribution of men, women, children on board')

titanic_df.groupby(['pclass', 'who']).size().unstack().plot(kind = 'bar', figsize = (7, 7),\
    xlabel = 'class', ylabel = 'number of people', title = 'Class distribution of men, women, children on board')
# Out:
# <Axes: title={'center': 'Class distribution of men, women, children on board'}, xlabel='class', ylabel='number of people'>
